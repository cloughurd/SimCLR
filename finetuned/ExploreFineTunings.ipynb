# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
results = json.load(open('SCMTuned.json', 'r'))

# %%
plt.plot(results['train_loss'])

# %%
plt.plot(results['train_acc'])

# %%
idx, loss = zip(*results['val_loss'])
plt.plot(idx, loss)

# %%
idx, acc = zip(*results['val_acc'])
plt.plot(idx, acc)
